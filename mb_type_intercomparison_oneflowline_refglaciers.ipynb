# %% [markdown]
# # Mass balance type intercomparison with one flowline for all reference glaciers

# %%
import numpy as np
import netCDF4
import oggm
import matplotlib.pyplot as plt

from oggm.core.massbalance import MassBalanceModel
# necessary to import RandomMAssBalance and ConstantMassBalance for modified MultipleFlowlineModel
from oggm.core.massbalance import RandomMassBalance, ConstantMassBalance

from oggm import cfg
from oggm.cfg import SEC_IN_YEAR


from scipy.interpolate import interp1d
from scipy import optimize as optimization
# Locals
from oggm.cfg import SEC_IN_YEAR, SEC_IN_MONTH
from oggm.utils import (SuperclassMeta, lazy_property, floatyear_to_date,
                        date_to_floatyear, monthly_timeseries, ncDataset,
                        tolist, clip_min, clip_max, clip_array)
from oggm.exceptions import InvalidWorkflowError, InvalidParamsError

import scipy.stats as stats
from scipy.optimize import minimize
from oggm import cfg, utils, workflow, tasks
from oggm.core.massbalance import LinearMassBalance
from oggm.core import climate
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# pip install geopandas
import geopandas as gpd
# Out:
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/xarray/core/merge.py:10: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   PANDAS_TYPES = (pd.Series, pd.DataFrame, pd.Panel)

# %%
SMALL_SIZE = 20
MEDIUM_SIZE = 22
BIGGER_SIZE = 24
plt.rc('figure',figsize=(20,10))
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
# take only Alpine reference glaciers, all reference glaciers does not work because of init_glacier_directories ...
rgi_version = '61'
#rgi_region = '11'  # Region Central Europe
#path = utils.get_rgi_region_file(rgi_region, version=rgi_version)
#rgidf = gpd.read_file(path)

df, _ = utils.get_wgms_files()
# if for all 
ref_glaciers = df[df['RGI_REG']=='11']['RGI{}0_ID'.format(rgi_version[0])] #[df['RGI_REG']=='11']
# ref_glaciers = df['RGI{}0_ID'.format(rgi_version[0])] #[df['RGI_REG']=='11']

df = utils.get_rgi_glacier_entities(ref_glaciers.values) #, 'RGI-60-11.01238'])

# %%
# import the new models
from mbmod_daily_oneflowline import *
#import help_func
import scipy
# Start after the prepro task level
import os
cfg.initialize()
working_dir = '/home/lilianschuster/Schreibtisch/PhD/oggm_files/oneFlowline'
# this needs to be changed if working on another computer
if not os.path.exists(working_dir):
    working_dir = utils.gettempdir(dirname='OGGM_mb_type_intercomparison', reset=True)
    
cfg.PATHS['working_dir'] = working_dir

cfg.PARAMS['baseline_climate'] = 'ERA5_daily'
base_url = 'https://cluster.klima.uni-bremen.de/~fmaussion/gdirs/prepro_l2_202010/elevbands_fl'
gdirs = workflow.init_glacier_directories(df, from_prepro_level=2, prepro_border=40, 
                                          prepro_base_url=base_url, prepro_rgi_version='62')

from help_func import compute_stat, minimize_bias, optimize_std_quot_brentq
# Out:
# 2021-01-04 09:41:40: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2021-01-04 09:41:40: oggm.cfg: Multiprocessing switched ON according to the parameter file.
# 2021-01-04 09:41:40: oggm.cfg: Multiprocessing: using all available processors (N=8)
# 2021-01-04 09:41:40: oggm.cfg: PARAMS['baseline_climate'] changed from `CRU` to `ERA5_daily`.
# 2021-01-04 09:41:40: oggm.workflow: init_glacier_directories from prepro level 2 on 66 glaciers.
# 2021-01-04 09:41:40: oggm.workflow: Execute entity task gdir_from_prepro on 66 glaciers
# 2021-01-04 09:41:41: oggm.utils: No known hash for cluster.klima.uni-bremen.de/~fmaussion/gdirs/prepro_l2_202010/elevbands_fl/RGI62/b_040/L2/RGI60-11/RGI60-11.00.tar
# 2021-01-04 09:41:41: oggm.utils: No known hash for cluster.klima.uni-bremen.de/~fmaussion/gdirs/prepro_l2_202010/elevbands_fl/RGI62/b_040/L2/RGI60-11/RGI60-11.01.tar
# 2021-01-04 09:41:41: oggm.utils: No known hash for cluster.klima.uni-bremen.de/~fmaussion/gdirs/prepro_l2_202010/elevbands_fl/RGI62/b_040/L2/RGI60-11/RGI60-11.02.tar
# 2021-01-04 09:41:41: oggm.utils: No known hash for cluster.klima.uni-bremen.de/~fmaussion/gdirs/prepro_l2_202010/elevbands_fl/RGI62/b_040/L2/RGI60-11/RGI60-11.03.tar

# %% [markdown]
# ---

# %%
# create a pandas dataframe
# this is not the best way to do this:
# xarray dataset with mb_type+grad & rgi_id as dimensions and DDF_opt and stats(RMSD,bias,rcor,std_quot) as variables 

pd_mb_data = pd.DataFrame(df['RGIId'].values)
pd_mb_data.index = pd_mb_data[0]

for mb_type in ['mb_monthly', 'mb_daily', 'mb_real_daily']:
    for grad in ['cte', 'var_an_cycle']:
        pd_mb_data['DDF_opt_{}_{}'.format(mb_type, grad)] = np.NaN
        pd_mb_data['stats_{}_{}'.format(mb_type, grad)] = np.NaN

# %% [markdown]
# ### compute how well the mass balance is modelled and plot this for all Alpine reference glaciers
#
# save the optimised DDF, statistics & ...  in pd_mb_data

# %%
pf = 2.5
N= 5000
loop = False
for gd in gdirs:
    try:
        # need ERA5dr climate if not mb_real_daily 
        cfg.PARAMS['baseline_climate'] = 'ERA5dr'
        oggm.shop.ecmwf.process_ecmwf_data(gd, dataset = 'ERA5dr')
        mbdf = gd.get_ref_mb_data()
        h, w = gd.get_inversion_flowline_hw()
        plt.figure(figsize=(24,15))
        plt.plot(mbdf.index,mbdf.ANNUAL_BALANCE, label = 'observed', color = 'black', lw = 2)
        for mb_type in ['mb_monthly', 'mb_daily']: 
            for grad in ['cte', 'var_an_cycle']:        

                pd_mb_data.loc[gd.rgi_id, 'DDF_opt_{}_{}'.format(mb_type, grad)] = scipy.optimize.brentq(minimize_bias,1,10000, xtol = 0.01,
                                            args=(mb_type, grad, gd, N, 2.5, loop, False) )
                gd_mb = mb_modules(gd, pd_mb_data.loc[gd.rgi_id, 'DDF_opt_{}_{}'.format(mb_type, grad)],
                                   mb_type=mb_type,     grad_type=grad, prcp_fac = pf, loop = loop) #, input_filesuffix=rgi_filesuffix, **kwargs)
                mb_specific = gd_mb.get_specific_mb(heights = h, widths = w,  year = mbdf.index.values)
                label_part1 = 'modeled {} {} gradient: '.format(mb_type, grad)
                pd_mb_data.loc[gd.rgi_id,'stats_{}_{}'.format(mb_type, grad)] = [compute_stat(mb_specific=mb_specific, mbdf=mbdf, return_dict = True, return_plot = label_part1)]
        
        # need ERA5_daily climate for mb_real_daily 
        cfg.PARAMS['baseline_climate'] = 'ERA5_daily'
        process_era5_daily_data(gd)
        for mb_type in ['mb_real_daily']:
            for grad in ['cte', 'var_an_cycle']:   
                pd_mb_data.loc[gd.rgi_id, 'DDF_opt_{}_{}'.format(mb_type, grad)] = scipy.optimize.brentq(minimize_bias,1,10000, xtol = 0.01,
                                            args=(mb_type, grad, gd, N, 2.5, loop, False) )
                gd_mb = mb_modules(gd, pd_mb_data.loc[gd.rgi_id, 'DDF_opt_{}_{}'.format(mb_type, grad)],
                                   mb_type=mb_type,     grad_type=grad, prcp_fac = pf, loop = loop) #, input_filesuffix=rgi_filesuffix, **kwargs)
                mb_specific = gd_mb.get_specific_mb(heights = h, widths = w,  year = mbdf.index.values)
                label_part1 = 'modeled {} {} gradient: '.format(mb_type, grad)
                pd_mb_data.loc[gd.rgi_id,'stats_{}_{}'.format(mb_type, grad)] = [compute_stat(mb_specific=mb_specific, mbdf=mbdf, return_dict = True, return_plot = label_part1)]



        plt.ylabel('SMB (kg m$^{-2}$ yr$^{-1}$)');

        plt.xlabel('year')
        plt.title(gd.rgi_id)
        plt.legend()

        plt.savefig('./figures_alps_indiv/mb_one_flowline_{}_N_{}.pdf'.format(gd.rgi_id,N))
        plt.close()
    except:
        print(gd.rgi_id)
        plt.close()

pd_mb_data.to_csv('stats_Alps_6mb_models_N_{}_with_mean_an_cycle.csv'.format(N))
# Out:
# 2021-01-04 09:46:06: oggm.cfg: PARAMS['baseline_climate'] changed from `ERA5_daily` to `ERA5dr`.
# 2021-01-04 09:46:06: oggm.shop.ecmwf: (RGI60-11.00002) process_ecmwf_data
# 2021-01-04 09:46:09: oggm.utils: /home/lilianschuster/OGGM/download_cache/cluster.klima.uni-bremen.de/~oggm/climate/era5/monthly/vdr/ERA5_temp_monthly.nc verified successfully.
# 2021-01-04 09:46:13: oggm.utils: /home/lilianschuster/OGGM/download_cache/cluster.klima.uni-bremen.de/~oggm/climate/era5/monthly/vdr/ERA5_totalprecip_monthly.nc verified successfully.
# 2021-01-04 09:46:17: oggm.utils: /home/lilianschuster/OGGM/download_cache/cluster.klima.uni-bremen.de/~oggm/climate/era5/monthly/vdr/ERA5_geopotential_monthly.nc verified successfully.
# 2021-01-04 09:46:33: oggm.utils: /home/lilianschuster/OGGM/download_cache/cluster.klima.uni-bremen.de/~oggm/climate/era5/monthly/vdr/ERA5_lapserates_monthly.nc verified successfully.
# 2021-01-04 09:46:48: oggm.utils: /home/lilianschuster/OGGM/download_cache/cluster.klima.uni-bremen.de/~oggm/climate/era5/monthly/vdr/ERA5_tempstd_monthly.nc verified successfully.
# 2021-01-04 09:46:50: oggm.cfg: PARAMS['baseline_climate'] changed from `ERA5dr` to `ERA5_daily`.
# 2021-01-04 09:46:50: oggm.shop.ecmwf: (RGI60-11.00002) process_era5_daily_data
# 2021-01-04 09:46:50: oggm.utils: No known hash for cluster.klima.uni-bremen.de/~oggm/climate/era5/daily/v1.0/era5_daily_t2m_1979-2018_flat.nc
# 2021-01-04 09:46:51: oggm.utils: No known hash for cluster.klima.uni-bremen.de/~oggm/climate/era5/daily/v1.0/era5_glacier_invariant_flat.nc
# 2021-01-04 09:46:52: oggm.cfg: PARAMS['baseline_climate'] changed from `ERA5_daily` to `ERA5dr`.
# 2021-01-04 09:46:52: oggm.shop.ecmwf: (RGI60-11.00012) process_ecmwf_data
# 2021-01-04 09:46:53: oggm.shop.ecmwf: (RGI60-11.00073) process_ecmwf_data
# RGI60-11.00012
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2522: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2522: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2522: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2522: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# 2021-01-04 09:46:53: oggm.cfg: PARAMS['baseline_climate'] changed from `ERA5dr` to `ERA5_daily`.
# 2021-01-04 09:46:53: oggm.shop.ecmwf: (RGI60-11.00073) process_era5_daily_data
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2522: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2522: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /home/lilianschuster/anaconda3/envs/oggm_test/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# 2021-01-04 09:46:54: oggm.cfg: PARAMS['baseline_climate'] changed from `ERA5_daily` to `ERA5dr`.
# 2021-01-04 09:46:54: oggm.shop.ecmwf: (RGI60-11.00080) process_ecmwf_data
# 2021-01-04 09:46:58: oggm.cfg: PARAMS['baseline_climate'] changed from `ERA5dr` to `ERA5_daily`.
# 2021-01-04 09
oggm.cfg: PARAMS['baseline_climate'] changed from `ERA5dr` to `ERA5_daily`.
# 2021-01-04 09:51:10: oggm.shop.ecmwf: (RGI60-11.03638) process_era5_daily_data
# 2021-01-04 09:51:11: oggm.cfg: PARAMS['baseline_climate'] changed from `ERA5_daily` to `ERA5dr`.
# 2021-01-04 09:51:11: oggm.shop.ecmwf: (RGI60-11.03643) process_ecmwf_data
# 2021-01-04 09:51:11: oggm.shop.ecmwf: (RGI60-11.03671) process_ecmwf_data
# RGI60-11.03643
# 2021-01-04 09:51:15: oggm.cfg: PARAMS['baseline_climate'] changed from `ERA5dr` to `ERA5_daily`.
# 2021-01-04 09:51:15: oggm.shop.ecmwf: (RGI60-11.03671) process_era5_daily_data
# 2021-01-04 09:51:16: oggm.cfg: PARAMS['baseline_climate'] changed from `ERA5_daily` to `ERA5dr`.
# 2021-01-04 09:51:16: oggm.shop.ecmwf: (RGI60-11.03674) process_ecmwf_data
# 2021-01-04 09:51:22: oggm.cfg: PARAMS['baseline_climate'] changed from `ERA5dr` to `ERA5_daily`.
# 2021-01-04 09:51:22: oggm.shop.ecmwf: (RGI60-11.03674) process_era5_daily_data
# 2021-01-04 09:51:23: oggm.cfg: PARAMS['baseline_climate'] changed from `ERA5_daily` to `ERA5dr`.
# 2021-01-04 09:51:23: oggm.shop.ecmwf: (RGI60-11.03756) process_ecmwf_data
# 2021-01-04 09:51:27: oggm.cfg: PARAMS['baseline_climate'] changed from `ERA5dr` to `ERA5_daily`.
# 2021-01-04 09:51:27: oggm.shop.ecmwf: (RGI60-11.03756) process_era5_daily_data

# %%
pd_mb_data
# Out:
#                              0  DDF_opt_mb_monthly_cte  \
# 0
# RGI60-11.00002  RGI60-11.00002              162.336704
# RGI60-11.00012  RGI60-11.00012                     NaN
# RGI60-11.00073  RGI60-11.00073              347.380969
# RGI60-11.00080  RGI60-11.00080              249.528927
# RGI60-11.00106  RGI60-11.00106              244.362436
# ...                        ...                     ...
# RGI60-11.03638  RGI60-11.03638              209.345509
# RGI60-11.03643  RGI60-11.03643                     NaN
# RGI60-11.03671  RGI60-11.03671              163.654858
# RGI60-11.03674  RGI60-11.03674              307.403182
# RGI60-11.03756  RGI60-11.03756              254.456293
#
#                                              stats_mb_monthly_cte  \
# 0
# RGI60-11.00002  {'RMSD': 85.2026731783895, 'bias': 6.181008234...
# RGI60-11.00012                                                NaN
# RGI60-11.00073  {'RMSD': 3.8070075106588774e-05, 'bias': -3.80...
# RGI60-11.00080  {'RMSD': 117.42395604323033, 'bias': -6.042995...
# RGI60-11.00106  {'RMSD': 123.23629006690192, 'bias': -9.806697...
# ...                                                           ...
# RGI60-11.03638  {'RMSD': 96.05522152511573, 'bias': 6.83266401...
# RGI60-11.03643                                                NaN
# RGI60-11.03671  {'RMSD': 78.8962026941356, 'bias': -5.35172746...
# RGI60-11.03674  {'RMSD': 113.57254091268882, 'bias': 0.0001896...
# RGI60-11.03756  {'RMSD': 125.73602883019628, 'bias': -0.000107...
#
#                 DDF_opt_mb_monthly_var_an_cycle  \
# 0
# RGI60-11.00002                       131.713232
# RGI60-11.00012                              NaN
# RGI60-11.00073                       234.331659
# RGI60-11.00080                       203.476933
# RGI60-11.00106                       212.695607
# ...                                         ...
# RGI60-11.03638                       184.240421
# RGI60-11.03643                              NaN
# RGI60-11.03671                       148.889093
# RGI60-11.03674                       247.641454
# RGI60-11.03756                       223.493480
#
#                                     stats_mb_monthly_var_an_cycle  \
# 0
# RGI60-11.00002  {'RMSD': 82.26456680369107, 'bias': 0.00014996...
# RGI60-11.00012                                                NaN
# RGI60-11.00073  {'RMSD': 5.1658128882081655e-05, 'bias': -5.16...
# RGI60-11.00080  {'RMSD': 111.11206103101148, 'bias': 5.7973386...
# RGI60-11.00106  {'RMSD': 112.92882935724548, 'bias': 6.9453356...
# ...                                                           ...
# RGI60-11.03638  {'RMSD': 89.85894816123741, 'bias': 7.80916446...
# RGI60-11.03643                                                NaN
# RGI60-11.03671  {'RMSD': 78.35967775511905, 'bias': -0.0001157...
# RGI60-11.03674  {'RMSD': 102.41345192043771, 'bias': 7.8398698...
# RGI60-11.03756  {'RMSD': 120.27571511448517, 'bias': -8.691336...
#
#                 DDF_opt_mb_daily_cte  \
# 0
# RGI60-11.00002            142.439549
# RGI60-11.00012                   NaN
# RGI60-11.00073            256.319129
# RGI60-11.00080            204.861811
# RGI60-11.00106            205.871378
# ...                              ...
# RGI60-11.03638            185.683121
# RGI60-11.03643                   NaN
# RGI60-11.03671            147.456474
# RGI60-11.03674            267.563991
# RGI60-11.03756            228.847439
#
#                                                stats_mb_daily_cte  \
# 0
# RGI60-11.00002  {'RMSD': 80.32073342553144, 'bias': -0.0450286...
# RGI60-11.00012                                                NaN
# RGI60-11.00073  {'RMSD': 0.05124615345403072, 'bias': -0.05124...
# RGI60-11.00080  {'RMSD': 106.50391784661221, 'bias': -0.061531...
# RGI60-11.00106  {'RMSD': 104.46459578093757, 'bias': -0.057242...
# ...                                                           ...
# RGI60-11.03638  {'RMSD': 89.80801994749443, 'bias': -0.0507930...
# RGI60-11.03643                                                NaN
# RGI60-11.03671  {'RMSD': 70.08490386745596, 'bias': -0.0402268...
# RGI60-11.03674  {'RMSD': 94.62282121413337, 'bias': -0.0699736...
# RGI60-11.03756  {'RMSD': 114.05616608173904, 'bias': -0.059726...
#
#                 DDF_opt_mb_daily_var_an_cycle  \
# 0
# RGI60-11.00002                     117.413726
# RGI60-11.00012                            NaN
# RGI60-11.00073                     185.251292
# RGI60-11.00080                     171.790798
# RGI60-11.00106                     181.940511
# ...                                       ...
# RGI60-11.03638                     165.123558
# RGI60-11.03643                            NaN
# RGI60-11.03671                     134.980214
# RGI60-11.03674                     220.292915
# RGI60-11.03756                     202.534269
#
#                                       stats_mb_daily_var_an_cycle  \
# 0
# RGI60-11.00002  {'RMSD': 86.10870582635012, 'bias': -0.0384542...
# RGI60-11.00012                                                NaN
# RGI60-11.00073  {'RMSD': 0.04345412340001076, 'bias': -0.04345...
# RGI60-11.00080  {'RMSD': 104.62658304140328, 'bias': -0.053320...
# RGI60-11.00106  {'RMSD': 98.2260706828189, 'bias': -0.05214938...
# ...                                                           ...
# RGI60-11.03638  {'RMSD': 85.6001868130294, 'bias': -0.04671352...
# RGI60-11.03643                                                NaN
# RGI60-11.03671  {'RMSD': 70.3287075833161, 'bias': -0.03762276...
# RGI60-11.03674  {'RMSD': 89.11799047410287, 'bias': -0.0607222...
# RGI60-11.03756  {'RMSD': 111.3157286765164, 'bias': -0.0551079...
#
#                 DDF_opt_mb_real_daily_cte  \
# 0
# RGI60-11.00002                 144.316305
# RGI60-11.00012                        NaN
# RGI60-11.00073                 266.959851
# RGI60-11.00080                 208.068058
# RGI60-11.00106                 206.106552
# ...                                   ...
# RGI60-11.03638                 185.250596
# RGI60-11.03643                        NaN
# RGI60-11.03671                 147.027413
# RGI60-11.03674                 266.709939
# RGI60-11.03756                 227.606326
#
#                                           stats_mb_real_daily_cte  \
# 0
# RGI60-11.00002  {'RMSD': 75.27244104537084, 'bias': 0.00027017...
# RGI60-11.00012                                                NaN
# RGI60-11.00073  {'RMSD': 0.00021377356313223572, 'bias': 0.000...
# RGI60-11.00080  {'RMSD': 96.99937430858677, 'bias': 7.73478047...
# RGI60-11.00106  {'RMSD': 97.96346965101718, 'bias': -4.2296311...
# ...                                                           ...
# RGI60-11.03638  {'RMSD': 88.78081249811751, 'bias': 6.33201193...
# RGI60-11.03643                                                NaN
# RGI60-11.03671  {'RMSD': 68.59258108116806, 'bias': -0.0002008...
# RGI60-11.03674  {'RMSD': 94.4074911234103, 'bias': 8.181852717...
# RGI60-11.03756  {'RMSD': 113.73702655652411, 'bias': 1.1175072...
#
#                 DDF_opt_mb_real_daily_var_an_cycle  \
# 0
# RGI60-11.00002                          109.259364
# RGI60-11.00012                                 NaN
# RGI60-11.00073                          188.850426
# RGI60-11.00080                          163.033301
# RGI60-11.00106                          172.925847
# ...                                            ...
# RGI60-11.03638                          156.057436
# RGI60-11.03643                                 NaN
# RGI60-11.03671                          128.823763
# RGI60-11.03674                          202.230351
# RGI60-11.03756                          189.067288
#
#                                  stats_mb_real_daily_var_an_cycle
# 0
# RGI60-11.00002  {'RMSD': 93.6000405170309, 'bias': 0.000180391...
# RGI60-11.00012                                                NaN
# RGI60-11.00073  {'RMSD': 9.349113815915189e-05, 'bias': 9.3491...
# RGI60-11.00080  {'RMSD': 96.27093179630721, 'bias': 0.00013408...
# RGI60-11.00106  {'RMSD': 89.8592588269464, 'bias': 2.107506952...
# ...                                                           ...
# RGI60-11.03638  {'RMSD': 82.24563966797747, 'bias': 3.77145316...
# RGI60-11.03643                                                NaN
# RGI60-11.03671  {'RMSD': 68.63641834035748, 'bias': -2.9282897...
# RGI60-11.03674  {'RMSD': 88.74556938463309, 'bias': 3.38601587...
# RGI60-11.03756  {'RMSD': 111.39891215676998, 'bias': -0.000149...
#
# [66 rows x 13 columns]

# %%
pd_mb_data = pd.read_csv('stats_Alps_6mb_models_N_{}_with_mean_an_cycle.csv'.format(N))

# this is a bit complicated because the dict value entries were saved as string and not as dict type in pandas somehow
# therefore I need ast.literal_eval to read the csv file ...
import ast

def get_stats(stat = 'RMSD', mb_type = 'mb_daily', grad_type = 'cte'):
    stats = []
    for k in np.arange(len(pd_mb_data)):
        #print(k)
        #if np.isnan(pd_mb_data['stats_mb_daily_cte'].values[k]):
        #    print('x')
        #    RMSD.append(np.NaN)
        stats_type = 'stats_{}_{}'.format(mb_type,grad_type)
        try:
            if type(pd_mb_data[stats_type].values[k]) == list:
                stats.append(pd_mb_data[stats_type].values[k][0][stat])
            else:
                stats.append(pd_mb_data[stats_type].values[k][stat])

        except:
            #RMSD.append(np.NaN)
            pass
        try:
            if type(ast.literal_eval(pd_mb_data[stats_type].values[k])) == list:

                stats.append(ast.literal_eval(pd_mb_data[stats_type].values[k])[0][stat])
                # print('y')

            else:
                stats.append(ast.literal_eval(pd_mb_data[stats_type].values[k])[stat])

        except:
            #RMSD.append(np.NaN)
            pass
    return np.array(stats)[~np.isnan(stats)]

# %% [markdown]
# # Plots of model performance statistics for all Alpine reference glaciers (without cross validation)

# %% [markdown]
# ### 1. DDF values

# %%
plt.figure(figsize=(25,10))
li_plot = []
li_label = []
for mb_type in ['mb_monthly','mb_daily', 'mb_real_daily']: #,'mb_real_daily']:
        for grad in ['cte','var_an_cycle']:
            li_plot.append(pd_mb_data['DDF_opt_{}_{}'.format(mb_type,grad)][~np.isnan(pd_mb_data['DDF_opt_{}_{}'.format(mb_type,grad)])])
            li_label.append(mb_type[3:]+'_'+grad)
plt.boxplot(li_plot, labels =li_label)
plt.ylabel('DDF (kg m$^{-2}$ mth$^{-1}$ K$^{-1}$)') 
plt.xlabel('mb_types')
plt.savefig('./figures_alps/alps_6mbtypes_DDF.pdf')

# %% [markdown]
# - a more complicated mass balance module resutls in DDF that are lower
#     - if not a cte gradient is used anymore, the lapse rate is different resulting in smaller DDFs
#     - if std (daily_cte) or real daily temperature data are used, the DDF is smaller because even for months with no temperatures above the threshold,
#         melting occurs ...

# %% [markdown]
# ### 2. Performance measures

# %%
plt.figure(figsize=(35,20))
plt.suptitle('MB metrics without cross validation')
for f, stats_type in enumerate(['RMSD','bias','rcor','quot_std']):
    plt.subplot(2,2,f+1)
    plt.boxplot([np.array(get_stats(stat = stats_type, mb_type = 'mb_monthly', grad_type = 'cte')),
                np.array(get_stats(stat = stats_type, mb_type = 'mb_monthly', grad_type = 'var_an_cycle')),
                np.array(get_stats(stat = stats_type, mb_type = 'mb_daily', grad_type = 'cte')),
                np.array(get_stats(stat = stats_type, mb_type = 'mb_daily', grad_type = 'var_an_cycle')),
                np.array(get_stats(stat = stats_type, mb_type = 'mb_real_daily', grad_type = 'cte')),
                np.array(get_stats(stat = stats_type, mb_type = 'mb_real_daily', grad_type = 'var_an_cycle')),
                ],
                labels = ['monthly_cte', 'monthly_var','daily_cte', 'daily_var', 'real_daily_cte', 'real_daily_var'])
    plt.ylabel(stats_type)
    plt.xticks()
    plt.xlabel('mb types')
    #if stats_type =='RMSD':
    #    plt.ylim([-10,500])
    #if stats_type =='std_quot':
    #    plt.ylim([-0.1,4])
    if (stats_type =='RMSD') or (stats_type =='bias'):
        plt.axhline(0, lw=3, color='green')
    if (stats_type =='rcor') or (stats_type =='quot_std'):
        plt.axhline(1, lw=3, color='green')
plt.savefig('./figures_alps/stats_one_flowline_N_{}_59Alps_refglaciers_var_6mb_types_with_mean_an_cycle.pdf'.format(N))

# %% [markdown]
# - more complex mb modules seem to perform better (when no cross-validation used)
# - if N is increased, the bias for mb_daily would go more to zero (but the bias does not need to be calibrated that exactly... and a smaller N is much faster)
