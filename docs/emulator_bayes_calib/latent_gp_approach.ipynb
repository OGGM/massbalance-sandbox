# %%
name = 'lily'

# %%
if name == 'lily':
    pass
else:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)

# %%
import numpy as np

# %%
t_bws= np.array([4.852,4.404,4.213,3.534,3.028,3.187,3.732])
t_ba= np.array([4.675,4.016,3.413,3.235,4.522,3.685,4.159])

# %%
print(np.average(t_bws), np.median(t_bws))
# Out:
# 3.85 3.732

# %%
print(np.average(t_ba), np.median(t_ba))
# Out:
# 3.9578571428571423 4.016

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
#import torch
import matplotlib.pyplot as plt
import matplotlib
import os
import sklearn
import sklearn.model_selection

import pymc as pm
import arviz as az

# %matplotlib inline

# %%
import aesara.tensor as at

# %%
print(pm.__version__)
# Out:
# 4.2.1

# %% [markdown]
# ### Import Data

# %%
if name == 'lily':
    data_path = '/home/lilianschuster/massbalance-sandbox/docs/emulator_bayes_calib/'
else:
    data_path = '/content/drive/MyDrive/massbalance-sandbox/docs/emulator_bayes_calib/'

# %%
# load specific MB mean for different MB model parameters (i.e. temp_b & melt_f, here done as a test for the Aletsch glacier): 
# choose the one with a fixed pf but variable temp. b and melt factors
pd_spec_mb = pd.read_csv(data_path+'test_mb_RGI60-11.01450_fixed_pf_test.csv', index_col=[0])

# too many values make the notebook slow ... I just removed some parameters again ... 
pd_spec_mb = pd_spec_mb.sort_values(by=['melt_f', 'temp_bias']).iloc[1::3]
pd_spec_mb = pd_spec_mb.sort_values(by=['temp_bias','melt_f']).iloc[::2]

# applied MB model parameters that were used to estimated the real OGGM MB model (partly used for training the emulator)  
X = pd_spec_mb[['temp_bias','melt_f'] ].values 

# modelled specific mean MB (mean over 2000-2020) estimated from the real OGGM MB model (partly used for training the emulator) 
# we later want to match this value (i.e. y) with the geodetic observation 
y = pd_spec_mb['spec_mb_mean'].values

# %% [markdown]
# Check on the dataframe

# %%
pd_spec_mb[['temp_bias','melt_f', 'spec_mb_mean']]
# Out:
#        temp_bias  melt_f  spec_mb_mean
# 99         -9.95    15.0   4447.609466
# 101        -9.95    35.0   4442.662098
# 103        -9.95    55.0   4437.714730
# 105        -9.95    75.0   4432.767362
# 107        -9.95    95.0   4427.819994
# ...          ...     ...           ...
# 19791       9.85   915.0 -74043.378533
# 19793       9.85   935.0 -75693.041314
# 19795       9.85   955.0 -77342.704096
# 19797       9.85   975.0 -78992.366877
# 19799       9.85   995.0 -80642.029659
#
# [3317 rows x 3 columns]

# %% [markdown]
# Following Lily's normalization routine

# %%
random_state = 42 
### similar as what David Rounce does in PyGEM:

# normalize parameter data used inside "real" MB model (partly used for training the emulator) 
X_mean = X.mean(axis=0)
X_std = X.std(axis=0)
X_norm = (X - X_mean) / X_std

# normalize modelled MB data from "real" MB model (partly used for training the emulator) 
y_mean = y.mean()
y_std = y.std()
y_norm = (y - y_mean) / y_std

# Split into training and test data (but witout having torch tensors ... )
X_train_pm,X_test_pm,y_train_pm,y_test_pm = sklearn.model_selection.train_test_split(X_norm,y_norm, test_size=0.8)

# %%
X_train_pm.shape
# Out:
# (663, 2)

# %% [markdown]
# ### Visualize the Simulated Data in 3D to ascertain fit shape
#
# This will help us figure out priors to test for GP fit

# %%
from mpl_toolkits import mplot3d

# %%
# %matplotlib inline

# %%
z = y_norm
x = X_norm[:,0]
y = X_norm[:,1]
 
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 

ax.scatter3D(x, y, z)
ax.set_xlabel('Temp Bias')
ax.set_ylabel('Melt Factor')
ax.set_zlabel('Mass Balance')

ax.view_init(5, 85)

# %% [markdown]
# There is some degeneracy in the y value for the melt factor and temp bias.

# %% [markdown]
# ### Geodetic Observations

# %%
sigma_geo = [171]
y_geo = [-1210]

# %% [markdown]
# ### Model Observations on Latent GP trained on Simulation

# %%
with pm.Model() as model:
    
    #define the covariance parameters and function
    input_dim = 2 #number of fit variables
    cov = pm.gp.cov.ExpQuad(input_dim, ls=0.1)
    
    #instantiate latent GP
    gp = pm.gp.Latent(cov_func=cov)
    f = gp.prior('latent_gp', X=X_train_pm, 
                 jitter=1e-7)
    
    #assuming marginal GP likelihood is normally distributed
    gp_likelihood = pm.Normal('gp_likelihood', mu=f, observed=y_train_pm)

    ###### For future, but not necessary now
    #assuming marginal GP likelihood is student-t distributed
    # gp_sigma = pm.HalfNormal('gp_sigma', sigma=2.0)
    # nu = 1 + pm.Gamma('nu', alpha=2, beta=0.1)
    # y_ = pm.StudentT('y', mu=f, lam=1.0/gp_sigma, nu=nu, 
    #                  observed=y_train_pm)

    # #assuming GP has some scatter
    # gp_sigma = pm.HalfCauchy('gp_sigma', beta=3)
    # latent_likelihood = gp.marginal_likelihood('gp_likelihood', 
    #                                            X=X_train_pm, y=y_train_pm, 
    #                                            sigma=gp_sigma)
    ######

    latent_trace = pm.sample(500, chains=2, target_accept=0.9, cores=1)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [latent_gp_rotated_]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 00:08&lt;00:00 Sampling chain 0, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 00:08&lt;00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 500 draw iterations (2_000 + 1_000 draws total) took 17 seconds.

# %%
with model:

    #define the "observational" variables for the geodetic best fit
    sigma = pm.ConstantData('sigma', sigma_geo)      # Lily: changed because of warning
    t_b = pm.TruncatedNormal('t_b', mu=0, sigma=2,
                            lower=-8, upper=8)
    melt_f = pm.TruncatedNormal('melt_f',
                                mu=250,
                                sigma=200,
                                lower=1, upper=1000)
    
    Xnew = at.stack(([t_b], [melt_f])).T
        
    #instantiate the conditional fit of GP to new "data"
    gp_mu = gp.conditional('conditional_fit', Xnew=Xnew)
    
    #specify the manifest model
    observed = pm.ConstantData('observed', y_geo)  # Lily: changed because of warning
    log_l = pm.Normal('log_mb', mu=gp_mu, sigma=sigma,
                      observed=observed)

# %%
# lily: this gives a ValueError: array must not contain infs or NaNs
with model:
    trace = pm.sample(500,chains=2, cores=1, return_inferencedata=True)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [latent_gp_rotated_, t_b, melt_f, conditional_fit]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='progress-bar-interrupted' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Intel MKL ERROR: Parameter 8 was incorrect on entry to DGEMV .
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/compile/function/types.py:971, in Function.__call__(self, *args, **kwargs)
#     969 try:
#     970     outputs = (
# --> 971         self.vm()
#     972         if output_subset is None
#     973         else self.vm(output_subset=output_subset)
#     974     )
#     975 except Exception:
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/graph/op.py:543, in Op.make_py_thunk.<locals>.rval(p, i, o, n, params)
#     539 @is_thunk_type
#     540 def rval(
#     541     p=p, i=node_input_storage, o=node_output_storage, n=node, params=None
#     542 ):
# --> 543     r = p(n, [x[0] for x in i], o)
#     544     for o in node.outputs:
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/tensor/slinalg.py:366, in SolveTriangular.perform(self, node, inputs, outputs)
#     365 A, b = inputs
# --> 366 outputs[0][0] = scipy.linalg.solve_triangular(
#     367     A,
#     368     b,
#     369     lower=self.lower,
#     370     trans=self.trans,
#     371     unit_diagonal=self.unit_diagonal,
#     372     check_finite=self.check_finite,
#     373 )
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/scipy/linalg/_basic.py:334, in solve_triangular(a, b, trans, lower, unit_diagonal, overwrite_b, check_finite)
#     333 a1 = _asarray_validated(a, check_finite=check_finite)
# --> 334 b1 = _asarray_validated(b, check_finite=check_finite)
#     335 if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/scipy/_lib/_util.py:287, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     286 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 287 a = toarray(a)
#     288 if not objects_ok:
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/numpy/lib/function_base.py:627, in asarray_chkfinite(a, dtype, order)
#     626 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 627     raise ValueError(
#     628         "array must not contain infs or NaNs")
#     629 return a
#
# ValueError: array must not contain infs or NaNs
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [40], line 3
#       1 # lily: this gives a ValueError: array must not contain infs or NaNs
#       2 with model:
# ----> 3     trace = pm.sample(500,chains=2, cores=1, return_inferencedata=True)
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/sampling.py:655, in sample(draws, step, init, n_init, initvals, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, callback, jitter_max_retries, return_inferencedata, idata_kwargs, mp_ctx, **kwargs)
#     653         _log.info(f"Sequential sampling ({chains} chains in 1 job)")
#     654         _print_step_hierarchy(step)
# --> 655         mtrace = _sample_many(**sample_args)
#     657 t_sampling = time.time() - t_start
#     658 # count the number of tune/draw iterations that happened
#     659 # ideally via the "tune" statistic, but not all samplers record it!
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/sampling.py:769, in _sample_many(draws, chain, chains, start, random_seed, step, callback, **kwargs)
#     767 traces: List[BaseTrace] = []
#     768 for i in range(chains):
# --> 769     trace = _sample(
#     770         draws=draws,
#     771         chain=chain + i,
#     772         start=start[i],
#     773         step=step,
#     774         random_seed=None if random_seed is None else random_seed[i],
#     775         callback=callback,
#     776         **kwargs,
#     777     )
#     778     if trace is None:
#     779         if len(traces) == 0:
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/sampling.py:915, in _sample(chain, progressbar, random_seed, start, draws, step, trace, tune, model, callback, **kwargs)
#     913 try:
#     914     strace = None
# --> 915     for it, (strace, diverging) in enumerate(sampling):
#     916         if it >= skip_first and diverging:
#     917             _pbar_data["divergences"] += 1
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/fastprogress/fastprogress.py:50, in ProgressBar.__iter__(self)
#      48 except Exception as e:
#      49     self.on_interrupt()
# ---> 50     raise e
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/fastprogress/fastprogress.py:41, in ProgressBar.__iter__(self)
#      39 if self.total != 0: self.update(0)
#      40 try:
# ---> 41     for i,o in enumerate(self.gen):
#      42         if self.total and i >= self.total: break
#      43         yield o
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/sampling.py:1062, in _iter_sample(draws, step, start, trace, chain, tune, model, random_seed, callback)
#    1060     step = stop_tuning(step)
#    1061 if step.generates_stats:
# -> 1062     point, stats = step.step(point)
#    1063     if strace.supports_sampler_stats:
#    1064         strace.record(point, stats)
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/step_methods/arraystep.py:286, in GradientSharedStep.step(self, point)
#     284 def step(self, point):
#     285     self._logp_dlogp_func._extra_are_set = True
# --> 286     return super().step(point)
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/step_methods/arraystep.py:208, in ArrayStepShared.step(self, point)
#     204     shared_var.set_value(point[name])
#     206 q = DictToArrayBijection.map({v.name: point[v.name] for v in self.vars})
# --> 208 step_res = self.astep(q)
#     210 if self.generates_stats:
#     211     apoint, stats = step_res
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/step_methods/hmc/base_hmc.py:156, in BaseHMC.astep(self, q0)
#     153 p0 = self.potential.random()
#     154 p0 = RaveledVars(p0, q0.point_map_info)
# --> 156 start = self.integrator.compute_state(q0, p0)
#     158 if not np.isfinite(start.energy):
#     159     model = self._model
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/step_methods/hmc/integration.py:47, in CpuLeapfrogIntegrator.compute_state(self, q, p)
#      44 if q.data.dtype != self._dtype or p.data.dtype != self._dtype:
#      45     raise ValueError("Invalid dtype. Must be %s" % self._dtype)
# ---> 47 logp, dlogp = self._logp_dlogp_func(q)
#      49 v = self._potential.velocity(p.data)
#      50 kinetic = self._potential.energy(p.data, velocity=v)
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/model.py:410, in ValueGradFunction.__call__(self, grad_vars, grad_out, extra_vars)
#     407 if isinstance(grad_vars, RaveledVars):
#     408     grad_vars = list(DictToArrayBijection.rmap(grad_vars).values())
# --> 410 cost, *grads = self._aesara_function(*grad_vars)
#     412 if grads:
#     413     grads_raveled = DictToArrayBijection.map(
#     414         {v.name: gv for v, gv in zip(self._grad_vars, grads)}
#     415     )
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/compile/function/types.py:984, in Function.__call__(self, *args, **kwargs)
#     982     if hasattr(self.vm, "thunks"):
#     983         thunk = self.vm.thunks[self.vm.position_of_error]
# --> 984     raise_with_op(
#     985         self.maker.fgraph,
#     986         node=self.vm.nodes[self.vm.position_of_error],
#     987         thunk=thunk,
#     988         storage_map=getattr(self.vm, "storage_map", None),
#     989     )
#     990 else:
#     991     # old-style linkers raise their own exceptions
#     992     raise
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/link/utils.py:534, in raise_with_op(fgraph, node, thunk, exc_info, storage_map)
#     529     warnings.warn(
#     530         f"{exc_type} error does not allow us to add an extra error message"
#     531     )
#     532     # Some exception need extra parameter in inputs. So forget the
#     533     # extra long error message in that case.
# --> 534 raise exc_value.with_traceback(exc_trace)
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/compile/function/types.py:971, in Function.__call__(self, *args, **kwargs)
#     968 t0_fn = time.time()
#     969 try:
#     970     outputs = (
# --> 971         self.vm()
#     972         if output_subset is None
#     973         else self.vm(output_subset=output_subset)
#     974     )
#     975 except Exception:
#     976     restore_defaults()
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/graph/op.py:543, in Op.make_py_thunk.<locals>.rval(p, i, o, n, params)
#     539 @is_thunk_type
#     540 def rval(
#     541     p=p, i=node_input_storage, o=node_output_storage, n=node, params=None
#     542 ):
# --> 543     r = p(n, [x[0] for x in i], o)
#     544     for o in node.outputs:
#     545         compute_map[o][0] = True
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/tensor/slinalg.py:366, in SolveTriangular.perform(self, node, inputs, outputs)
#     364 def perform(self, node, inputs, outputs):
#     365     A, b = inputs
# --> 366     outputs[0][0] = scipy.linalg.solve_triangular(
#     367         A,
#     368         b,
#     369         lower=self.lower,
#     370         trans=self.trans,
#     371         unit_diagonal=self.unit_diagonal,
#     372         check_finite=self.check_finite,
#     373     )
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/scipy/linalg/_basic.py:334, in solve_triangular(a, b, trans, lower, unit_diagonal, overwrite_b, check_finite)
#     267 """
#     268 Solve the equation `a x = b` for `x`, assuming a is a triangular matrix.
#     269
#    (...)
#     330
#     331 """
#     333 a1 = _asarray_validated(a, check_finite=check_finite)
# --> 334 b1 = _asarray_validated(b, check_finite=check_finite)
#     335 if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     336     raise ValueError('expected square matrix')
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/scipy/_lib/_util.py:287, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     285         raise ValueError('masked arrays are not supported')
#     286 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 287 a = toarray(a)
#     288 if not objects_ok:
#     289     if a.dtype is np.dtype('O'):
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/numpy/lib/function_base.py:627, in asarray_chkfinite(a, dtype, order)
#     625 a = asarray(a, dtype=dtype, order=order)
#     626 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 627     raise ValueError(
#     628         "array must not contain infs or NaNs")
#     629 return a
#
# ValueError: array must not contain infs or NaNs
# Apply node that caused the error: SolveTriangular{lower=False, trans=0, unit_diagonal=False, check_finite=True}(TensorConstant{[[ 1.00000..671e-001]]}, CGemv{inplace}.0)
# Toposort index: 89
# Inputs types: [TensorType(float64, (663, 663)), TensorType(float64, (None,))]
# Inputs shapes: [(663, 663), (663,)]
# Inputs strides: [(5304, 8), (8,)]
# Inputs values: ['not shown', 'not shown']
# Outputs clients: [[CGemv{no_inplace}(latent_gp_rotated_, (d__logp/dmelt_f_interval___logprob){1.0}, TensorConstant{[[ 1.00000..042e-001]]}, SolveTriangular{lower=False, trans=0, unit_diagonal=False, check_finite=True}.0, TensorConstant{-1.0})]]
#
# Backtrace when the node is created (use Aesara flag traceback__limit=N to make it longer):
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 623, in grad
#     _rval: Sequence[Variable] = _populate_grad_dict(
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1434, in _populate_grad_dict
#     rval = [access_grad_cache(elem) for elem in wrt]
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1434, in <listcomp>
#     rval = [access_grad_cache(elem) for elem in wrt]
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1387, in access_grad_cache
#     term = access_term_cache(node)[idx]
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1058, in access_term_cache
#     output_grads = [access_grad_cache(var) for var in node.outputs]
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1058, in <listcomp>
#     output_grads = [access_grad_cache(var) for var in node.outputs]
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1387, in access_grad_cache
#     term = access_term_cache(node)[idx]
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1213, in access_term_cache
#     input_grads = node.op.L_op(inputs, node.outputs, new_output_grads)
#
# HINT: Use the Aesara flag `exception_verbosity=high` for a debug print-out and storage map footprint of this Apply node.

# %%
# lily: this gives a ValueError: array must not contain infs or NaNs
with model:
    trace = pm.sample(
        init="jitter+adapt_diag_grad",
        random_seed=42, chains=4, target_accept=0.8, cores=1
    )
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag_grad...
# Sequential sampling (4 chains in 1 job)
# NUTS: [latent_gp_rotated_, t_b, melt_f, conditional_fit]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='progress-bar-interrupted' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# Intel MKL ERROR: Parameter 8 was incorrect on entry to DGEMV .
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/compile/function/types.py:971, in Function.__call__(self, *args, **kwargs)
#     969 try:
#     970     outputs = (
# --> 971         self.vm()
#     972         if output_subset is None
#     973         else self.vm(output_subset=output_subset)
#     974     )
#     975 except Exception:
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/graph/op.py:543, in Op.make_py_thunk.<locals>.rval(p, i, o, n, params)
#     539 @is_thunk_type
#     540 def rval(
#     541     p=p, i=node_input_storage, o=node_output_storage, n=node, params=None
#     542 ):
# --> 543     r = p(n, [x[0] for x in i], o)
#     544     for o in node.outputs:
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/tensor/slinalg.py:366, in SolveTriangular.perform(self, node, inputs, outputs)
#     365 A, b = inputs
# --> 366 outputs[0][0] = scipy.linalg.solve_triangular(
#     367     A,
#     368     b,
#     369     lower=self.lower,
#     370     trans=self.trans,
#     371     unit_diagonal=self.unit_diagonal,
#     372     check_finite=self.check_finite,
#     373 )
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/scipy/linalg/_basic.py:334, in solve_triangular(a, b, trans, lower, unit_diagonal, overwrite_b, check_finite)
#     333 a1 = _asarray_validated(a, check_finite=check_finite)
# --> 334 b1 = _asarray_validated(b, check_finite=check_finite)
#     335 if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/scipy/_lib/_util.py:287, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     286 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 287 a = toarray(a)
#     288 if not objects_ok:
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/numpy/lib/function_base.py:627, in asarray_chkfinite(a, dtype, order)
#     626 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 627     raise ValueError(
#     628         "array must not contain infs or NaNs")
#     629 return a
#
# ValueError: array must not contain infs or NaNs
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [38], line 3
#       1 # lily: this gives a ValueError: array must not contain infs or NaNs
#       2 with model:
# ----> 3     trace = pm.sample(
#       4         init="jitter+adapt_diag_grad",
#       5         random_seed=42, chains=4, target_accept=0.8, cores=1
#       6     )
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/sampling.py:655, in sample(draws, step, init, n_init, initvals, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, callback, jitter_max_retries, return_inferencedata, idata_kwargs, mp_ctx, **kwargs)
#     653         _log.info(f"Sequential sampling ({chains} chains in 1 job)")
#     654         _print_step_hierarchy(step)
# --> 655         mtrace = _sample_many(**sample_args)
#     657 t_sampling = time.time() - t_start
#     658 # count the number of tune/draw iterations that happened
#     659 # ideally via the "tune" statistic, but not all samplers record it!
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/sampling.py:769, in _sample_many(draws, chain, chains, start, random_seed, step, callback, **kwargs)
#     767 traces: List[BaseTrace] = []
#     768 for i in range(chains):
# --> 769     trace = _sample(
#     770         draws=draws,
#     771         chain=chain + i,
#     772         start=start[i],
#     773         step=step,
#     774         random_seed=None if random_seed is None else random_seed[i],
#     775         callback=callback,
#     776         **kwargs,
#     777     )
#     778     if trace is None:
#     779         if len(traces) == 0:
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/sampling.py:915, in _sample(chain, progressbar, random_seed, start, draws, step, trace, tune, model, callback, **kwargs)
#     913 try:
#     914     strace = None
# --> 915     for it, (strace, diverging) in enumerate(sampling):
#     916         if it >= skip_first and diverging:
#     917             _pbar_data["divergences"] += 1
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/fastprogress/fastprogress.py:50, in ProgressBar.__iter__(self)
#      48 except Exception as e:
#      49     self.on_interrupt()
# ---> 50     raise e
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/fastprogress/fastprogress.py:41, in ProgressBar.__iter__(self)
#      39 if self.total != 0: self.update(0)
#      40 try:
# ---> 41     for i,o in enumerate(self.gen):
#      42         if self.total and i >= self.total: break
#      43         yield o
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/sampling.py:1062, in _iter_sample(draws, step, start, trace, chain, tune, model, random_seed, callback)
#    1060     step = stop_tuning(step)
#    1061 if step.generates_stats:
# -> 1062     point, stats = step.step(point)
#    1063     if strace.supports_sampler_stats:
#    1064         strace.record(point, stats)
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/step_methods/arraystep.py:286, in GradientSharedStep.step(self, point)
#     284 def step(self, point):
#     285     self._logp_dlogp_func._extra_are_set = True
# --> 286     return super().step(point)
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/step_methods/arraystep.py:208, in ArrayStepShared.step(self, point)
#     204     shared_var.set_value(point[name])
#     206 q = DictToArrayBijection.map({v.name: point[v.name] for v in self.vars})
# --> 208 step_res = self.astep(q)
#     210 if self.generates_stats:
#     211     apoint, stats = step_res
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/step_methods/hmc/base_hmc.py:156, in BaseHMC.astep(self, q0)
#     153 p0 = self.potential.random()
#     154 p0 = RaveledVars(p0, q0.point_map_info)
# --> 156 start = self.integrator.compute_state(q0, p0)
#     158 if not np.isfinite(start.energy):
#     159     model = self._model
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/step_methods/hmc/integration.py:47, in CpuLeapfrogIntegrator.compute_state(self, q, p)
#      44 if q.data.dtype != self._dtype or p.data.dtype != self._dtype:
#      45     raise ValueError("Invalid dtype. Must be %s" % self._dtype)
# ---> 47 logp, dlogp = self._logp_dlogp_func(q)
#      49 v = self._potential.velocity(p.data)
#      50 kinetic = self._potential.energy(p.data, velocity=v)
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/pymc/model.py:410, in ValueGradFunction.__call__(self, grad_vars, grad_out, extra_vars)
#     407 if isinstance(grad_vars, RaveledVars):
#     408     grad_vars = list(DictToArrayBijection.rmap(grad_vars).values())
# --> 410 cost, *grads = self._aesara_function(*grad_vars)
#     412 if grads:
#     413     grads_raveled = DictToArrayBijection.map(
#     414         {v.name: gv for v, gv in zip(self._grad_vars, grads)}
#     415     )
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/compile/function/types.py:984, in Function.__call__(self, *args, **kwargs)
#     982     if hasattr(self.vm, "thunks"):
#     983         thunk = self.vm.thunks[self.vm.position_of_error]
# --> 984     raise_with_op(
#     985         self.maker.fgraph,
#     986         node=self.vm.nodes[self.vm.position_of_error],
#     987         thunk=thunk,
#     988         storage_map=getattr(self.vm, "storage_map", None),
#     989     )
#     990 else:
#     991     # old-style linkers raise their own exceptions
#     992     raise
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/link/utils.py:534, in raise_with_op(fgraph, node, thunk, exc_info, storage_map)
#     529     warnings.warn(
#     530         f"{exc_type} error does not allow us to add an extra error message"
#     531     )
#     532     # Some exception need extra parameter in inputs. So forget the
#     533     # extra long error message in that case.
# --> 534 raise exc_value.with_traceback(exc_trace)
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/compile/function/types.py:971, in Function.__call__(self, *args, **kwargs)
#     968 t0_fn = time.time()
#     969 try:
#     970     outputs = (
# --> 971         self.vm()
#     972         if output_subset is None
#     973         else self.vm(output_subset=output_subset)
#     974     )
#     975 except Exception:
#     976     restore_defaults()
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/graph/op.py:543, in Op.make_py_thunk.<locals>.rval(p, i, o, n, params)
#     539 @is_thunk_type
#     540 def rval(
#     541     p=p, i=node_input_storage, o=node_output_storage, n=node, params=None
#     542 ):
# --> 543     r = p(n, [x[0] for x in i], o)
#     544     for o in node.outputs:
#     545         compute_map[o][0] = True
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/tensor/slinalg.py:366, in SolveTriangular.perform(self, node, inputs, outputs)
#     364 def perform(self, node, inputs, outputs):
#     365     A, b = inputs
# --> 366     outputs[0][0] = scipy.linalg.solve_triangular(
#     367         A,
#     368         b,
#     369         lower=self.lower,
#     370         trans=self.trans,
#     371         unit_diagonal=self.unit_diagonal,
#     372         check_finite=self.check_finite,
#     373     )
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/scipy/linalg/_basic.py:334, in solve_triangular(a, b, trans, lower, unit_diagonal, overwrite_b, check_finite)
#     267 """
#     268 Solve the equation `a x = b` for `x`, assuming a is a triangular matrix.
#     269
#    (...)
#     330
#     331 """
#     333 a1 = _asarray_validated(a, check_finite=check_finite)
# --> 334 b1 = _asarray_validated(b, check_finite=check_finite)
#     335 if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     336     raise ValueError('expected square matrix')
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/scipy/_lib/_util.py:287, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     285         raise ValueError('masked arrays are not supported')
#     286 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 287 a = toarray(a)
#     288 if not objects_ok:
#     289     if a.dtype is np.dtype('O'):
#
# File ~/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/numpy/lib/function_base.py:627, in asarray_chkfinite(a, dtype, order)
#     625 a = asarray(a, dtype=dtype, order=order)
#     626 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 627     raise ValueError(
#     628         "array must not contain infs or NaNs")
#     629 return a
#
# ValueError: array must not contain infs or NaNs
# Apply node that caused the error: SolveTriangular{lower=False, trans=0, unit_diagonal=False, check_finite=True}(TensorConstant{[[ 1.00000..671e-001]]}, CGemv{inplace}.0)
# Toposort index: 89
# Inputs types: [TensorType(float64, (663, 663)), TensorType(float64, (None,))]
# Inputs shapes: [(663, 663), (663,)]
# Inputs strides: [(5304, 8), (8,)]
# Inputs values: ['not shown', 'not shown']
# Outputs clients: [[CGemv{no_inplace}(latent_gp_rotated_, (d__logp/dmelt_f_interval___logprob){1.0}, TensorConstant{[[ 1.00000..042e-001]]}, SolveTriangular{lower=False, trans=0, unit_diagonal=False, check_finite=True}.0, TensorConstant{-1.0})]]
#
# Backtrace when the node is created (use Aesara flag traceback__limit=N to make it longer):
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 623, in grad
#     _rval: Sequence[Variable] = _populate_grad_dict(
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1434, in _populate_grad_dict
#     rval = [access_grad_cache(elem) for elem in wrt]
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1434, in <listcomp>
#     rval = [access_grad_cache(elem) for elem in wrt]
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1387, in access_grad_cache
#     term = access_term_cache(node)[idx]
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1058, in access_term_cache
#     output_grads = [access_grad_cache(var) for var in node.outputs]
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1058, in <listcomp>
#     output_grads = [access_grad_cache(var) for var in node.outputs]
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1387, in access_grad_cache
#     term = access_term_cache(node)[idx]
#   File "/home/lilianschuster/micromamba/envs/oggm_pymc/lib/python3.9/site-packages/aesara/gradient.py", line 1213, in access_term_cache
#     input_grads = node.op.L_op(inputs, node.outputs, new_output_grads)
#
# HINT: Use the Aesara flag `exception_verbosity=high` for a debug print-out and storage map footprint of this Apply node.

# %%
axs = az.plot_trace(trace, var_names=['t_b', 'melt_f', 
                                      'conditional_fit'], filter_vars="like")
axs[0,0].figure.tight_layout();

# %%
with model:
  predicted_samples = pm.sample_posterior_predictive(trace, var_names=['log_mb'])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:00&lt;00:00]
#     </div>

# %%
axs = az.plot_trace(predicted_samples.posterior_predictive, filter_vars="like")
axs[0,0].figure.tight_layout();
